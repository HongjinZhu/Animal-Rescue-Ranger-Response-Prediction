# %% [markdown]
# <a href="https://colab.research.google.com/github/HongjinZhu/Animal-Rescue-Ranger-Response-Prediction/blob/main/temporal_trends_in_calls.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Install packages and load the dataset

# %%
# !pip install kaggle
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# download dataset
# !kaggle datasets download -d mexwell/urban-park-ranger-animal-condition-response
# Out:
# ...
# Dataset URL: https://www.kaggle.com/datasets/mexwell/urban-park-ranger-animal-condition-response
# License(s): other
# ...
# 100% 200k/200k [00:00<00:00, 686kB/s]
# 100% 200k/200k [00:00<00:00, 685kB/s]

# %%
# from google.colab import files
# files.upload()

import zipfile
import os

with zipfile.ZipFile('urban-park-ranger-animal-condition-response.zip', 'r') as zip_ref:
    zip_ref.extractall('.')

os.listdir('.')
# Out:
# ['.config',
#  'kaggle.json',
#  'Urban_Park_Ranger_Animal_Condition_Response_20240702.csv',
#  'urban-park-ranger-animal-condition-response.zip',
#  'sample_data']

# %%
import pandas as pd

df = pd.read_csv('Urban_Park_Ranger_Animal_Condition_Response_20240702.csv')
df
# Out:
#      Date and Time of initial call Date and time of Ranger response  \
# 0           06/23/2021 04:45:00 PM           06/24/2021 08:00:00 AM
# 1           06/24/2021 10:00:00 AM           06/24/2021 11:00:00 AM
# 2           06/23/2021 02:30:00 PM           06/23/2021 02:30:00 PM
# 3           06/23/2021 01:00:00 PM           06/23/2021 01:10:00 PM
# 4           06/23/2021 09:20:00 AM           06/23/2021 09:20:00 AM
# ...                            ...                              ...
# 5061        06/29/2023 03:00:00 PM           06/29/2023 03:00:00 PM
# 5062        06/29/2023 04:30:00 PM           06/29/2023 04:45:00 AM
# 5063        06/30/2023 10:00:00 AM           06/30/2023 10:15:00 AM
# 5064        06/30/2023 04:00:00 PM           06/30/2023 04:00:00 PM
# 5065        06/30/2023 05:00:00 PM           06/30/2023 05:00:00 PM
#
#             Borough                          Property  \
# 0          Brooklyn                    Sternberg Park
# ...

# %% [markdown]
# # Descriptive Analysis

# %% [markdown]
# ## Temporal Trends in Calls

# %%
df['Date'] = df['Date and Time of initial call'].dt.date
df['Hour'] = df['Date and Time of initial call'].dt.hour
df['Month'] = df['Date and Time of initial call'].dt.month
df['DayOfWeek'] = df['Date and Time of initial call'].dt.dayofweek

# statistics
date_stats = df.groupby('Date').size().reset_index(name='Count')
print(date_stats.describe())

# time series analysis
plt.figure(figsize=(15, 8))
df.groupby('Date').size().plot()
plt.title('Number of Calls Over Time')
plt.xlabel('Date')
plt.ylabel('Number of Calls')
plt.show()

# calls by hour of day
plt.figure(figsize=(15, 8))
sns.countplot(data=df, x='Hour')
plt.title('Number of Calls by Hour of Day')
plt.xlabel('Hour of Day')
plt.ylabel('Number of Calls')
plt.show()

# calls by day of week
plt.figure(figsize=(15, 8))
sns.countplot(data=df, x='DayOfWeek')
plt.title('Number of Calls by Day of Week')
plt.xlabel('Day of Week')
plt.ylabel('Number of Calls')
plt.xticks(ticks=range(7), labels=['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun'])
plt.show()

# calls by month
plt.figure(figsize=(15, 8))
sns.countplot(data=df, x='Month')
plt.title('Number of Calls by Month')
plt.xlabel('Month')
plt.ylabel('Number of Calls')
plt.show()
# Out:
#              Count
# count  1645.000000
# mean      3.079635
# std       2.070322
# min       1.000000
# 25%       1.000000
# 50%       3.000000
# 75%       4.000000
# max      15.000000
